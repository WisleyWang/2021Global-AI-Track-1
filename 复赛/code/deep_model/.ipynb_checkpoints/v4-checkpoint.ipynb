# %%
import pandas as pd
import numpy as np
from  tensorflow.compat.v1 import keras
import tensorflow.compat.v1.keras.backend as K
from tensorflow.compat.v1.keras import Model
from tensorflow.compat.v1.keras import initializers, regularizers, constraints
from tensorflow.compat.v1.keras.layers import *
from tensorflow.compat.v1.keras.layers import Embedding, Dense, CuDNNLSTM,CuDNNGRU, Bidirectional,SpatialDropout1D,Input,GlobalAveragePooling1D,GlobalMaxPooling1D,Conv1D,concatenate,Dropout,Activation,BatchNormalization,Concatenate,Add,MaxPooling1D,Flatten,AveragePooling1D
from gensim.models import Word2Vec
from tensorflow.compat.v1.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.compat.v1.keras.preprocessing.sequence import pad_sequences
from tensorflow.compat.v1.keras.preprocessing import text, sequence
import gensim, logging
from tensorflow.compat.v1.keras.callbacks import EarlyStopping,ModelCheckpoint
from sklearn.model_selection import KFold,StratifiedShuffleSplit,StratifiedKFold
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from keras_lookahead import Lookahead

# %%
train=pd.read_csv('../tcdata/train.csv',header=None)
test=pd.read_csv('../tcdata/track1_round1_testB.csv',header=None)
# test=pd.read_csv('../tcdata/testA.csv',header=None)
data=pd.concat([train,test],axis=0)
data[1]=data[1].apply(lambda x:x.strip().replace('|',''))

# %%
## 制作标签
### 创建训练集标签 
train_labels1=np.zeros((len(train),17),dtype='int8')
noncase=0
for cnt,i in enumerate(train[2]):
    if i:
        lab=[int(x.replace('|','').strip()) for x in i.split(' ') if x and x!='|']
        for l in lab:
            train_labels1[cnt,l]=1
    else:
        noncase+=1
print('noncase label1:',noncase)
#----------------------------------
noncase=0
train_labels2=np.zeros((len(train),12),dtype='int8')
for cnt,i in enumerate(train[3]):
    if pd.notna(i):
        lab=[int(x.replace('|','').strip()) for x in i.split(' ') if x and x!='|']
        for l in lab:
            train_labels2[cnt,l]=1
    else:
        noncase+=1
print('noncase label2:',noncase)
# Out:
# noncase label1: 0
# noncase label2: 8247

# %%
cate_num=train_labels1.sum(1)+train_labels2.sum(1)

# %%
## 生成全部的训练文本
data1=pd.read_csv('../tcdata/track1_round1_train_20210222.csv',header=None)
data2=pd.read_csv('../tcdata/track1_round1_testA_20210222.csv',header=None)
data3=pd.read_csv('../tcdata/track1_round1_testB.csv',header=None)
text_data=pd.concat([train,data1,data2,data3],axis=0)
text_data[1]=text_data[1].apply(lambda x:x.strip().replace('|',''))
text_data[1].to_csv('../tmp/all_data.txt',header=False,index=False)

# %%
text_data=pd.read_csv('../tmp/all_data.txt',header=None)

# %%
w2v=Word2Vec(text_data[0].apply(lambda x:x.split(' ')).tolist(),size=512, window=8, iter=100, min_count=2,
                     sg=1, sample=0.002, workers=6 , seed=1017)

w2v.wv.save_word2vec_format('../tmp/w2v_512.txt')
# Out:
# 2021-04-22 14:44:39,442 : INFO : collecting all words and their counts
# 2021-04-22 14:44:39,443 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021
: INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-04-22 15:06:00,288 : INFO : EPOCH - 100 : training on 1369423 raw words (1015966 effective words) took 12.7s, 79741 effective words/s
# 2021-04-22 15:06:00,289 : INFO : training on a 136942300 raw words (101582039 effective words) took 1280.4s, 79334 effective words/s
# 2021-04-22 15:06:00,338 : INFO : storing 859x512 projection weights into ../tmp/w2v_512.txt

# %%
tokenizer = Tokenizer(lower=False, char_level=False, split=' ')
tokenizer.fit_on_texts(data[1].tolist())
seq = tokenizer.texts_to_sequences(data[1].tolist())
# 分训练和测试集合
seq = pad_sequences(seq, maxlen=128, value=0)
train_seq=np.asarray(seq[:len(train)])
test_seq=seq[len(train):]

# %%
embedding_matrix=np.zeros((len(tokenizer.word_index)+1,128))
w2v=gensim.models.KeyedVectors.load_word2vec_format(
        '../tmp/w2v_128.txt', binary=False)

for word in tokenizer.word_index:
    if word not in w2v.wv.vocab:
        continue
    embedding_matrix[tokenizer.word_index[word]] = w2v[word]
embedding_matrix.shape
# Out:
# 2021-04-22 15:20:27,883 : INFO : loading projection weights from ../tmp/w2v_128.txt
# 2021-04-22 15:20:28,015 : INFO : loaded (859, 128) matrix from ../tmp/w2v_128.txt
# <ipython-input-26-6203a5121046>:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   if word not in w2v.wv.vocab:
# (859, 128)

# %%
def NN_huaweiv1(maxlen,embedding_matrix=None,class_num1=17,class_num2=12):    
    emb_layer = Embedding(
       embedding_matrix.shape[0], embedding_matrix.shape[1],input_length=maxlen,weights=[embedding_matrix],trainable=True,
    )
    seq1 = Input(shape=(maxlen,)) 
    
    x1 = emb_layer(seq1)
    sdrop=SpatialDropout1D(rate=0.2)
    
    lstm_layer = Bidirectional(CuDNNGRU(128, return_sequences=True))
    gru_layer = Bidirectional(CuDNNGRU(128, return_sequences=True))
#     lstm_layer1 = Bidirectional(CuDNNLSTM(128, return_sequences=True))
#     cnn1d_layer=Conv1D(64, kernel_size=3, padding="same", kernel_initializer="he_uniform")
    x1 = sdrop(x1)
    lstm1 = lstm_layer(x1)
#     att_dot=AttentionDot()(lstm1)
    
    gru1 = gru_layer(TimestepDropout(0.2)(lstm1))
    att_1 = Attention(maxlen)(lstm1)
    att_2 = Attention(maxlen)(gru1)

#     cnn1 = cnn1d_layer(lstm1)
    avg_pool = GlobalAveragePooling1D()
    max_pool = GlobalMaxPooling1D()

    x1=Add()([att_1,att_2])
    x = Dropout(0.2)(Activation(activation="relu")(BatchNormalization()(Dense(128)(x1))))
    x = Activation(activation="relu")(BatchNormalization()(Dense(64)(x)))
    pred1 = Dense(class_num1, activation='sigmoid',name='pred1')(x)
    
    y=Dropout(0.2)(concatenate([x1,x]))
    y = Activation(activation="relu")(BatchNormalization()(Dense(128)(x)))
    pred2=Dense(class_num2, activation='sigmoid',name='pred2')(y)
    
    model = Model(inputs=seq1, outputs=[pred1,pred2])
    return model

class TimestepDropout(Dropout):
    def __init__(self, rate, **kwargs):
        super(TimestepDropout, self).__init__(rate, **kwargs)
        self.input_spec = InputSpec(ndim=3)
    def _get_noise_shape(self, inputs):
        input_shape = K.shape(inputs)
        noise_shape = (input_shape[0], 1,input_shape[2])
        return noise_shape
class AttentionSelf(Layer):
    """
        self attention,
        codes from:  https://mp.weixin.qq.com/s/qmJnyFMkXVjYBwoR_AQLVA
    """
    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(AttentionSelf,self).__init__(**kwargs)

    def build(self, input_shape):
        # W、K and V
        self.kernel = self.add_weight(name='WKV'.format(self.name),
                                        shape=(3, input_shape[-1], self.output_dim),
                                        initializer='uniform',
                                        regularizer=regularizers.L1L2(0.0000032),
                                        trainable=True)
#         super().build(input_shape)

    def call(self, x):
        WQ = K.dot(x, self.kernel[0])
        WK = K.dot(x, self.kernel[1])
        WV = K.dot(x, self.kernel[2])
        # print("WQ.shape",WQ.shape)
        # print("K.permute_dimensions(WK, [0, 2, 1]).shape",K.permute_dimensions(WK, [0, 2, 1]).shape)
        QK = K.batch_dot(WQ, K.permute_dimensions(WK, [0, 2, 1]))
        QK = QK / (64**0.5)
        QK = K.softmax(QK)
        # print("QK.shape",QK.shape)
        V = K.batch_dot(QK, WV)
        return V

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1], self.output_dim)


class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        """
        Keras Layer that implements an Attention mechanism for temporal data.
        Supports Masking.
        Follows the work of Raffel et al. [https://arxiv.org/abs/1512.08756]
        # Input shape
            3D tensor with shape: `(samples, steps, features)`.
        # Output shape
            2D tensor with shape: `(samples, features)`.
        :param kwargs:
        Just put it on top of an RNN Layer (GRU/LSTM/SimpleRNN) with return_sequences=True.
        The dimensions are inferred based on the output shape of the RNN.
        Example:
            # 1
            model.add(LSTM(64, return_sequences=True))
            model.add(Attention())
            # next add a Dense layer (for classification/regression) or whatever...
            # 2
            hidden = LSTM(64, return_sequences=True)(words)
            sentence = Attention()(hidden)
            # next add a Dense layer (for classification/regression) or whatever...
        """
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0

        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3
#         print('-------------',type(input_shape))
        self.W = self.add_weight(name='{}_W'.format(self.name),
                                 shape=(input_shape[-1],),
                                 initializer=self.init,
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight(name='{}_b'.format(self.name),
                                     shape=(input_shape[1],),
                                     initializer='zero',
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        # do not pass the mask to the next layers
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        e = K.reshape(K.dot(K.reshape(x, (-1, features_dim)), K.reshape(self.W, (features_dim, 1))), (-1, step_dim))  # e = K.dot(x, self.W)
        if self.bias:
            e += self.b
        e = K.tanh(e)

        a = K.exp(e)
        # apply mask after the exp. will be re-normalized next
        if mask is not None:
            # cast the mask to floatX to avoid float64 upcasting in theano
            a *= K.cast(mask, K.floatx())
        # in some cases especially in the early stages of training the sum may be almost zero
        # and this results in NaN's. A workaround is to add a very small positive number ε to the sum.
        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())
        a = K.expand_dims(a)

        c = K.sum(a * x, axis=1)
        return c

    def compute_output_shape(self, input_shape):
        return input_shape[0], self.features_dim
def mean_pred(y_true, y_pred):
    return -K.mean(y_true*K.log(y_pred+1.e-7)+(1-y_true)*K.log(1-y_pred+1.e-7))*10

# %%
batch_size=32
epochs=100
weight_name='V4'
optimizer=keras.optimizers.Adam(0.001)
oof=np.zeros((len(train),29))
tmp=0
test_oof=np.zeros((len(test),29))
# for ii in range(17):
#     per_labels=train_labels[:,ii]
#     print('当前分类类别：'+str(ii))
#     print('正样本比例:'+str(sum(per_labels)/len(per_labels)))
# per_labels=train_labels[:,1]
folds=StratifiedKFold(n_splits=8,shuffle=True, random_state=2018) #2018
for fold_n, (trn_idx, val_idx) in enumerate(folds.split(train,cate_num)):
    print('Fold', fold_n)
    print('Build model...')
#     print('正样本比例:',train_labels[trn_idx].mean(0))
    model=NN_huaweiv1(maxlen=128,embedding_matrix=embedding_matrix)
#     model=multi_gpu_model(model,gpus=2)
    model.compile(optimizer, ['binary_crossentropy','binary_crossentropy'], metrics=['accuracy',mean_pred])
#     lookahead = Lookahead(k=5, alpha=0.5) # 初始化Lookahead
#     lookahead.inject(model) # 插入到模型中
    print('Train...')
    early_stopping = EarlyStopping(monitor='val_loss', patience=2,mode='min')
    check_point=ModelCheckpoint('../model_weight/%s_%d.h5'%(weight_name,fold_n),monitor='val_loss',verbose=1, save_best_only=True,save_weights_only=True)

    model.fit(train_seq[trn_idx],{'pred1':train_labels1[trn_idx],'pred2':train_labels2[trn_idx]},
              batch_size=batch_size,
              epochs=epochs,
              callbacks=[early_stopping,check_point],
              validation_data=(train_seq[val_idx],{'pred1':train_labels1[val_idx],'pred2':train_labels2[val_idx]}))
    model.load_weights('../model_weight/%s_%d.h5'%(weight_name,fold_n))
    oof[val_idx,:17],oof[val_idx,17:] = model.predict(train_seq[val_idx],batch_size=batch_size)
    tmp_test_pred1,tmp_test_pred2=model.predict(test_seq,batch_size=batch_size)
    test_oof[:,:17]+=tmp_test_pred1/folds.n_splits
    test_oof[:,17:]+=tmp_test_pred2/folds.n_splits
# Out:
# /home/lichangyv/miniconda3/envs/tf2/lib/python3.8/site-packages/sklearn/model_selection/_split.py:666: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=8.
#   warnings.warn(("The least populated class in y has only %d"
# Fold 0
# Build model...
# Train...
# Epoch 1/100
# 547/547 [==============================] - 28s 44ms/step - loss: 0.5431 - pred1_loss: 0.3235 - pred2_loss: 0.2197 - pred1_accuracy: 0.1996 - pred1_mean_pred: 3.2346 - pred2_accuracy: 0.3419 - pred2_mean_pred: 2.1967 - val_loss: 0.1851 - val_pred1_loss: 0.1224 - val_pred2_loss: 0.0627 - val_pred1_accuracy: 0.2436 - val_pred1_mean_pred: 1.2299 - val_pred2_accuracy: 0.5404 - val_pred2_mean_pred: 0.6209
#
# Epoch 00001: val_loss improved from inf to 0.18513, saving model to ../model_weight/V4_0.h5
# Epoch 2/100
# 547/547 [==============================] - 20s 37ms/step - loss: 0.1752 - pred1_loss: 0.1186 - pred2_loss: 0.0566 - pred1_accuracy: 0.2434 - pred1_mean_pred: 1.1861 - pred2_accuracy: 0.5004 - pred2_mean_pred: 0.5659 - val_loss: 0.1290 - val_pred1_loss: 0.0846 - val_pred2_loss: 0.0444 - val_pred1_accuracy: 0.3068 - val_pred1_mean_pred: 0.8558 - val_pred2_accuracy: 0.5324 - val_pred2_mean_pred: 0.4389
#
# Epoch 00002: val_loss improved from 0.18513 to 0.12899, saving model to ../model_weight/V4_0.h5
# Epoch 3/100
# 547/547 [==============================] - 20s 37ms/step - loss: 0.1279 - pred1_loss: 0.0831 - pred2_loss: 0.0447 - pred1_accuracy: 0.3515 - pred1_mean_pred: 0.8313 - pred2_accuracy: 0.5119 - pred2_mean_pred: 0.4475 - val_loss: 0.1047 - val_pred1_loss: 0.0627 - val_pred2_loss: 0.0420 - val_pred1_accuracy: 0.3572 - val_pred1_mean_pred: 0.6302 - val_pred2_accuracy: 0.6444 - val_pred2_mean_pred: 0.4157
#
# Epoch 00003: val_loss improved from 0.12899 to 0.10467, saving model to ../model_weight/V4_0.h5
# Epoch 4/100
# 547/547 [==============================] - 20s 37ms/step - loss: 0.1007 - pred1_loss: 0.0632 - pred2_loss: 0.0376 - pred1_accuracy: 0.3685 - pred1_mean_pred: 0.6316 - pred2_accuracy: 0.5221 - pred2_mean_pred: 0.3755 - val_loss: 0.0906 - val_pred1_loss: 0.0533 - val_pred2_loss: 0.0374 - val_pred1_accuracy: 0.3416 - val_pred1_mean_pred: 0.5379 - val_pred2_accuracy: 0.5064 - val_pred2_mean_pred: 0.3696
#
# Epoch 00004: val_loss improved from 0.10467 to 0.09063, saving model to ../model_weight/V4_0.h5
# Epoch 5/100
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0822 - pred1_loss: 0.0523 - pred2_loss: 0.0298 - pred1_accuracy: 0.3814 - pred1_mean_pred: 0.5234 - pred2_accuracy: 0.5417 - pred2_mean_pred: 0.2985 - val_loss: 0.0814 - val_pred1_loss: 0.0477 - val_pred2_loss: 0.0336 - val_pred1_accuracy: 0.4316 - val_pred1_mean_pred: 0.4876 - val_pred2_accuracy: 0.5200 - val_pred2_mean_pred: 0.3326
#
# Epoch 00005: val_loss improved from 0.09063 to 0.08135, saving model to ../model_weight/V4_0.h5
# Epoch 6/100
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0735 - pred1_loss: 0.0468 - pred2_loss: 0.0266 - pred1_accuracy: 0.3820 - pred1_mean_pred: 0.4683 - pred2_accuracy: 0.5393 - pred2_mean_pred: 0.2664 - val_loss: 0.0719 - val_pred1_loss: 0.0433 - val_pred2_loss: 0.0285 - val_pred1_accuracy: 0.3928 - val_pred1_mean_pred: 0.4393 - val_pred2_accuracy: 0.4936 - val_pred2_mean_pred: 0.2820
#
# Epoch 00006: val_loss improved from 0.08135 to 0.07185, saving model to ../model_weight/V4_0.h5
# Epoch 7/100
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0634 - pred1_loss: 0.0397 - pred2_loss: 0.0237 - pred1_accuracy: 0.3901 - pred1_mean_pred: 0.3969 - pred2_accuracy: 0.5291 - pred2_mean_pred: 0.2374 - val_loss: 0.0718 - val_pred1_loss: 0.0423 - val_pred2_loss: 0.0295 - val_pred1_accuracy: 0.4540 - val_pred1_mean_pred: 0.4249 - val_pred2_accuracy: 0.4856 - val_pred2_mean_pred: 0.2916
#
# Epoch 00007: val_loss improved from 0.07185 to 0.07177, saving model to ../model_weight/V4_0.h5
# Epoch 8/100
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0578 - pred1_loss: 0.0368 - pred2_loss: 0.0210 - pred1_accuracy: 0.4099 - pred1_mean_pred: 0.3678 - pred2_accuracy: 0.5215 - pred2_mean_pred: 0.2101 - val_loss: 0.0692 - val_pred1_loss: 0.0409 - val_pred2_loss: 0.0283 - val_pred1_accuracy: 0.3724 - val_pred1_mean_pred: 0.4165 - val_pred2_accuracy: 0.5044 - val_pred2_mean_pred: 0.2799
#
# Epoch 00008: val_loss improved from 0.07177 to 0.06923, saving model to ../model_weight/V4_0.h5
# Epoch 9/100
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0496 - pred1_loss: 0.0322 - pred2_loss: 0.0173 - pred1_accuracy: 0.3947 - pred1_mean_pred: 0.3223 - pred2_accuracy: 0.5323 - pred2_mean_pred: 0.1733 - val_loss: 0.0689 - val_pred1_loss: 0.0414 - val_pred2_loss: 0.0275 - val_pred1_accuracy: 0.4132 - val_pred1_mean_pred: 0.4244 - val_pred2_accuracy: 0.5288 - val_pred2_mean_pred: 0.2722
#
# Epoch 00009: val_loss improved from 0.06923 to 0.06889, saving model to ../model_weight/V4_0.h5
# Epoch 10/100
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0463 - pred1_loss: 0.0299 - pred2_loss: 0.0164 - pred1_accuracy: 0.4179 - pred1_mean_pred: 0.2994 - pred2_accuracy: 0.5433 - pred2_mean_pred: 0.1635 - val_loss: 0.0696 - val_pred1_loss: 0.0410 - val_pred2_loss: 0.0286 - val_pred1_accuracy: 0.3760 - val_pred1_mean_pred: 0.4122 - val_pred2_accuracy: 0.5124 - val_pred2_mean_pred: 0.2831
#
# Epoch 00010: val_loss did not improve from 0.06889
# Epoch 11/100
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0441 - pred1_loss: 0.0284 - pred2_loss: 0.0157 - pred1_accuracy: 0.4161 - pred1_mean_pred: 0.2844 - pred2_accuracy: 0.5382 - pred2_mean_pred: 0.1571 - val_loss: 0.0689 - val_pred1_loss: 0.0394 - val_pred2_loss: 0.0295 - val_pred1_accuracy: 0.3940 - val_pred1_mean_pred: 0.3970 - val_pred2_accuracy: 0.5484 - val_pred2_mean_pred: 0.2915
#
# Epoch 00011: val_loss improved from 0.06889 to 0.06886, saving model to ../model_weight/V4_0.h5
# Epoch 12/100
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0371 - pred1_loss: 0.0250 - pred2_loss: 0.0121 - pred1_accuracy: 0.4195 - pred1_mean_pred: 0.2496 - pred2_accuracy: 0.5390 - pred2_mean_pred: 0.1211 - val_loss: 0.0656 - val_pred1_loss: 0.0389 - val_pred2_loss: 0.0267 - val_pred1_accuracy: 0.3904 - val_pred1_mean_pred: 0.3958 - val_pred2_accuracy: 0.5028 - val_pred2_mean_pred: 0.2639
#
# Epoch 00012: val_loss improved from 0.06886 to 0.06559, saving model to ../model_weight/V4_0.h5
# Epoch 13/100
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0343 - pred1_loss: 0.0232 - pred2_loss: 0.0111 - pred1_accuracy: 0.4124 - pred1_mean_pred: 0.2319 - pred2_accuracy: 0.5372 - pred2_mean_pred: 0.1109 - val_loss: 0.0671 - val_pred1_loss: 0.0393 - val_pred2_loss: 0.0278 - val_pred1_accuracy: 0.3852 - val_pred1_mean_pred: 0.3998 - val_pred2_accuracy: 0.5196 - val_pred2_mean_pred: 0.2744
#
# Epoch 00013: val_loss did not improve from 0.06559
# Epoch 14/100
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0326 - pred1_loss: 0.0222 - pred2_loss: 0.0104 - pred1_accuracy: 0.4286 - pred1_mean_pred: 0.2222 - pred2_accuracy: 0.5427 - pred2_mean_pred: 0.1039 - val_loss: 0.0647 - val_pred1_loss: 0.0378 - val_pred2_loss: 0.0269 - val_pred1_accuracy: 0.3748 - val_pred1_mean_pred: 0.3807 - val_pred2_accuracy: 0.4988 - val_pred2_mean_pred: 0.2658
#
# Epoch 00014: val_loss improved from 0.06559 to 0.06473, saving model to ../model_weight/V4_0.h5
# Epoch 15/100
# 547/547 [==============================] - 21s 39ms/step - loss: 0.0293 - pred1_loss: 0.0199 - pred2_loss: 0.0094 - pred1_accuracy: 0.4146 - pred1_mean_pred: 0.1990 - pred2_accuracy: 0.5393 - pred2_mean_pred: 0.0944 - val_loss: 0.0644 - val_pred1_loss: 0.0395 - val_pred2_loss: 0.0249 - val_pred1_accuracy: 0.4228 - val_pred1_mean_pred: 0.3996 - val_pred2_accuracy: 0.5240 - val_pred2_mean_pred: 0.2463
#
# Epoch 00015: val_loss improved from 0.06473 to 0.06440, saving model to ../model_weight/V4_0.h5
# Epoch 16/100
# 547/547 [==============================] - 21s 38ms/step - loss: 0.0275 - pred1_loss: 0.0189 - pred2_loss: 0.0086 - pred1_accuracy: 0.4283 - pred1_mean_pred: 0.1889 - pred2_accuracy: 0.5344 - pred2_mean_pred: 0.0857 - val_loss: 0.0686 - val_pred1_loss: 0.0400 - val_pred2_loss: 0.0287 - val_pred1_accuracy: 0.4260 - val_pred1_mean_pred: 0.4009 - val_pred2_accuracy: 0.5108 - val_pred2_mean_pred: 0.2833
#
# Epoch 00016: val_loss did not improve from 0.06440
# Epoch 17/100
# 331/547 [=================>............] - ETA: 7s - loss: 0.0258 - pred1_loss: 0.0174 - pred2_loss: 0.0084 - pred1_accuracy: 0.4166 - pred1_mean_pred: 0.1740 - pred2_accuracy: 0.5496 - pred2_mean_pred: 0.0836
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-6e4e1c0d48ee> in <module>
#      25     check_point=ModelCheckpoint('../model_weight/%s_%d.h5'%(weight_name,fold_n),monitor='val_loss',verbose=1, save_best_only=True,save_weights_only=True)
#      26
# ---> 27     model.fit(train_seq[trn_idx],{'pred1':train_labels1[trn_idx],'pred2':train_labels2[trn_idx]},
#      28               batch_size=batch_size,
#      29               epochs=epochs,
#
# ~/miniconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/miniconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/miniconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/miniconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/miniconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~/miniconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~/miniconda3/envs/tf2/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
sub=pd.DataFrame()
sub['report_ID']=test[0]
sub['Prediction']=[ '|'+' '.join(['%.12f'%j for j in i]) for i in test_oof ]
sub.to_csv('../result.csv',index=False,header=False)
